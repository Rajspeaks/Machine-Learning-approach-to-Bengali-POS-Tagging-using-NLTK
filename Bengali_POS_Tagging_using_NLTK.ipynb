# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajspeaks/Bengali-POS-Tagging-using-NLTK-on-Indian-Corpus/blob/main/Bengali_POS_Tagging_using_NLTK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Bengali POS Tagging using NLTK on Indian Corpus**

# %%
import nltk
from nltk.corpus import indian
from nltk.tag import tnt
import string

# %%
nltk.download('indian')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package indian to /root/nltk_data...
# [nltk_data]   Unzipping corpora/indian.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
tagged_set = 'bangla.pos'
word_set = indian.sents(tagged_set)
count = 0
for sen in word_set:
    count = count + 1
    sen = "".join([" "+i if not i.startswith("'") and i not in string.punctuation else i for i in sen]).strip()
    print (count, sen)
print ('Total sentences in the tagged file are',count)

train_perc = .96

train_rows = int(train_perc*count)
test_rows = train_rows + 1

print ('Sentences to be trained',train_rows, 'Sentences to be tested against',test_rows)
# Out:
# 1 মহিষের সন্তান: তোড়া উপজাতি ৷
# 2 বাসস্থান-ঘরগৃহস্থালি তোড়া ভাষায় গ্রামকেও বলে` মোদ' ৷
# 3 মোদের আয়তন খুব বড়ো নয় ৷
# 4 প্রতি মোদে আছে কিছু কুঁড়েঘর, সাধারণ মহিষশালা ৷
# 5 আর গ্রামের বাইরে থাকে ডেয়ারি-মন্দির ৷
# 6 আয়তনের তারতম্য অনুসারে গ্রামগুলি দু রকমের: এতূডমোদ( বড়ো গ্রাম) ওকিনমোদ( ছোট গ্রাম) ৷
# 7 কোন কোন গ্রামের আবার ধর্মীয় বা_C﻿মহিষের সন্তান: তোড়া উপজাতি ৷
# 8 িকে বলে` সোতি-মোদ' ৷
# 9 কুঁড়েঘরগুলির আকার বাংলার বা ভারতের অন্য অঞ্চলের প্রচলিত কুঁড়ে ঘর নয় ৷
# 10 এগুলি দেখতে শোয়ানো পিপের মতো ৷
# 11 এক দিকের বাঁশের কাঠামো খিলানের মতো বেঁকে গিয়ে অন্যদিকের মাটিতে মিশেছে ৷
# 12 সেগুলি বেত জাতীয় লতা দিয়ে পরস্পর বাঁধা ৷
# 13 ঘরগুলি লম্বায় 18 ফুট, চওড়ায় 9 ফুট আর উচ্চতায় 10 ফুটের মতো ৷
# 14 উপরের ঢালু চাল ঘাস-পাতা দিয়ে মোটা করে ছাওয়া ৷
# 15 যাতে বৃষ্টির জল ভেতরে ঢুকতে না পারে ৷
# 16 কুঁড়ের সামনের দিকে একটি মাত্র দরজা, আর কোথাও কোন রকমের জানলা বা ঘুলঘুলি নেই ৷
# 17 ঘরের ভেতরে ডানদিকের মেঝে কিছুটা উঁচু করে তোলা- সেটি তাদের শোবার জায়গা ৷
# 18 বাঁদিকে অগ্নিকুণ্ড- তার পাশে রান্না করার জায়গা ৷
# ...

# %%
data = indian.tagged_sents(tagged_set)
train_data = data[:train_rows] 
test_data = data[test_rows:]
pos_tagger = tnt.TnT()
pos_tagger.train(train_data)
pos_tagger.evaluate(test_data)
# Out:
# 0.5122377622377622

# %% [markdown]
# For inputs entered below regarding POS Tagging is collected from [SNLTR](https://baniorachana.nltr.org/)

# %%
sentence = input()
tokenized = nltk.word_tokenize(sentence)
print(pos_tagger.tag(tokenized))
# Out:
# ১৮৬৩ সালে কলকাতার এক সম্ভ্রান্ত কায়স্থ পরিবারে স্বামী বিবেকানন্দের জন্ম। তাঁর চিন্তাচেতনার অন্যতম অনুপ্রেরণা ছিলেন তাঁর যুক্তিবাদী পিতা ও ধর্মপ্রাণা জননী। ছেলেবেলা থেকেই তাঁর মধ্যে অধ্যাত্মপিপাসা ও গভীর ঈশ্বরানুরাগ লক্ষিত হত। ঈশ্বরকে প্রত্যক্ষ করেছেন এমন এক ব্যক্তির সন্ধানে বেরিয়ে তিনি রামকৃষ্ণ পরমহংসের সান্নিধ্যে আসেন এবং পরে তাঁর শিষ্যত্ব গ্রহণ করেন। গুরু শ্রীরামকৃষ্ণ তাঁকে অদ্বৈত বেদান্তের শিক্ষা দেন। তাঁর কাছ থেকেই বিবেকানন্দ শেখেন যে সব ধর্মই সত্য এবং মানুষের সেবাই সর্বোৎকৃষ্ট ঈশ্বরোপাসনা। গুরুর মৃত্যুর পর সন্ন্যাস অবলম্বন করে তিনি সমগ্র ভারতীয় উপমহাদেশ পদব্রজে পর্যটন করেন। পরবর্তীকালে শিকাগো যাত্রা করে ১৮৯৩ সালের বিশ্বধর্ম মহাসভায় হিন্দুধর্মের প্রতিনিধিত্ব করেন। মার্কিন যুক্তরাষ্ট্রের বিভিন্ন ফোরাম, বিশ্ববিদ্যালয় ও সংঘ তাঁর বাগ্মীতায় মুগ্ধ হয়ে বক্তৃতাদানের আমন্ত্রণ জানান। একাধিক সাধারণ ও ব্যক্তিগত সভায় ভাষণ দিয়ে তিনি আমেরিকা, ইংল্যান্ড ও আরও কয়েকটি দেশে বেদান্ত, যোগশাস্ত্র ও হিন্দুধর্মকে সুপরিচিত করে তোলেন। আমেরিকা ও ইংল্যান্ডে তিনি স্থাপন করেন বেদান্ত সোসাইটি। ভারতে 
# ...
